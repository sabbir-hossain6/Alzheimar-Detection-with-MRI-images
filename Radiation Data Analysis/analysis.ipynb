# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

df = pd.read_csv("1000uCi_10m.csv", 
                 usecols=["x", "y", "counts"])
df.head()
# Out:
#             x           y  counts
# 0  262.616406  333.629258      37
# 1  264.240693  333.840528      45
# 2  267.132099  333.996201      53
# 3  267.132099  333.996201      41
# 4  269.496251  333.962843      36

# %%
df.plot(x="x", y="y", kind="scatter", c="counts",
        colormap="YlOrRd")
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>

# %%
df_bg = pd.read_csv("background.csv", 
                 usecols=["x", "y", "counts"])
df.plot(x="x", y="y", kind="scatter", c="counts", colormap="YlOrRd")
# Out:
# <AxesSubplot: xlabel='x', ylabel='y'>
